# %% [markdown]
# <a href="https://colab.research.google.com/github/Alishaw99/Hospitality_Analysis_PowerBI-main/blob/main/Part_1_Text%2C_Image_%2C_Speech_Generation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# STEP 1: Install the Google Generative AI SDK
# !pip install -q google-generativeai


import os
os.environ["GOOGLE_API_KEY"] = "AIzaSyB5auBbZFsDaIMYbYnb4Gn9iTmgQTWjxqQ"

# %% [markdown]
# # Text Generation

# %%
# from google import genai

# from google.genai import types
# client= genai.Client() # models

# #models.generate_content()
# #model
# #content-- prompt

# response = client.models.generate_content(model='gemini-2.5-pro', contents='What is an car , explain in 400 words')
# print(response.text)
# Out:
# A car, also known as an automobile, is a self-propelled, wheeled motor vehicle designed primarily for transporting a small number of people from one place to another. It is a cornerstone of modern life, providing personal freedom, mobility, and convenience on a scale that was unimaginable for most of human history.
#
# At its core, a car's function is defined by its powertrain, the system that generates power and delivers it to the wheels. For over a century, the dominant type has been the internal combustion engine (ICE). This engine works by burning fuel, such as gasoline or diesel, to create controlled explosions inside cylinders. These explosions push pistons, which turn a crankshaft, ultimately rotating the wheels through a system of gears called a transmission. In contrast, modern electric vehicles (EVs) use large rechargeable batteries to power one or more electric motors, which turn the wheels directly, offering a quieter and emission-free alternative.
#
# Beyond the engine or motor, a car is a complex assembly of integrated systems. Its foundation is the chassis, a rigid frame that supports the entire vehicle and all its components. The body is the outer shell that protects occupants from the elements and is designed for safety and aerodynamics. A car’s movement is managed by several key systems: the suspension system uses springs and shock absorbers to provide a smooth ride, the steering system allows the driver to control its direction, and the braking system provides the crucial ability to slow down and stop safely.
#
# The interior, or cabin, is the space for the driver and passengers, featuring seats, safety features like airbags and seatbelts, and controls such as a steering wheel, pedals, and a dashboard with instruments. The car is more than just a machine; it is a cultural icon and a vital economic driver. Its invention reshaped cities, created suburbs, and connected communities. Today, the car continues to evolve with advancements in autonomous (self-driving) technology, connectivity, and sustainable energy, promising to redefine transportation once again.

# %%
response   # data+metda_data
print(dir(response))
print(type(response))
# Out:
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__class_vars__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__fields__', '__fields_set__', '__format__', '__ge__', '__get_pydantic_core_schema__', '__get_pydantic_json_schema__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__pretty__', '__private_attributes__', '__pydantic_complete__', '__pydantic_computed_fields__', '__pydantic_core_schema__', '__pydantic_custom_init__', '__pydantic_decorators__', '__pydantic_extra__', '__pydantic_fields__', '__pydantic_fields_set__', '__pydantic_generic_metadata__', '__pydantic_init_subclass__', '__pydantic_on_complete__', '__pydantic_parent_namespace__', '__pydantic_post_init__', '__pydantic_private__', '__pydantic_root_model__', '__pydantic_serializer__', '__pydantic_setattr_handlers__', '__pydantic_validator__', '__reduce__', '__reduce_ex__', '__replace__', '__repr__', '__repr_args__', '__repr_name__', '__repr_recursion__', '__repr_str__', '__rich_repr__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_calculate_keys', '_check_field_type_mismatches', '_copy_and_set_values', '_from_response', '_get_text', '_get_value', '_iter', '_setattr_handler', 'automatic_function_calling_history', 'candidates', 'code_execution_result', 'construct', 'copy', 'create_time', 'dict', 'executable_code', 'from_orm', 'function_calls', 'json', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'model_version', 'parse_file', 'parse_obj', 'parse_raw', 'parsed', 'parts', 'prompt_feedback', 'response_id', 'schema', 'schema_json', 'sdk_http_response', 'text', 'to_json_dict', 'update_forward_refs', 'usage_metadata', 'validate']
# <class 'google.genai.types.GenerateContentResponse'>

# %%
response
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text="""A car, also known as an automobile, is a self-propelled, wheeled motor vehicle designed primarily for transporting a small number of people from one place to another. It is a cornerstone of modern life, providing personal freedom, mobility, and convenience on a scale that was unimaginable for most of human history.
#
# At its core, a car's function is defined by its powertrain, the system that generates power and delivers it to the wheels. For over a century, the dominant type has been the internal combustion engine (ICE). This engine works by burning fuel, such as gasoline or diesel, to create controlled explosions inside cylinders. These explosions push pistons, which turn a crankshaft, ultimately rotating the wheels through a system of gears called a transmission. In contrast, modern electric vehicles (EVs) use large rechargeable batteries to power one or more electric motors, which turn the wheels directly, offering a quieter and emission-free alternative.
#
# Beyond the engine or motor, a car is a complex assembly of integrated systems. Its foundation is the chassis, a rigid frame that supports the entire vehicle and all its components. The body is the outer shell that protects occupants from the elements and is designed for safety and aerodynamics. A car’s movement is managed by several key systems: the suspension system uses springs and shock absorbers to provide a smooth ride, the steering system allows the driver to control its direction, and the braking system provides the crucial ability to slow down and stop safely.
#
# The interior, or cabin, is the space for the driver and passengers, featuring seats, safety features like airbags and seatbelts, and controls such as a steering wheel, pedals, and a dashboard with instruments. The car is more than just a machine; it is a cultural icon and a vital economic driver. Its invention reshaped cities, created suburbs, and connected communities. Today, the car continues to evolve with advancements in autonomous (self-driving) technology, connectivity, and sustainable energy, promising to redefine transportation once again."""
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-pro',
#   response_id='0IRLaaCbHaibkdUP1IKm0Ak',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=10>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=402,
#     prompt_token_count=13,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=13
#       ),
#     ],
#     thoughts_token_count=1312,
#     total_token_count=1727
#   )
# )

# %%
#tokens

# %%
# prompt_token_count - This tells us how many tokens were in your prompt, i.e., the input you sent

# candidates_token_count- refers to the number of tokens in the final output — the actual answer the model generated for your input.These do
    # not include your input or internal reasoning. Just the actual answer.

# thoughts_token_count - This is Gemini-specific and unique to models that support "thinking" (chain-of-thought, tool-use, intermediate
    #reasoning).
    #It tells how many tokens were used by the model in its internal reasoning steps — for example:
          # Thinking out the answer
          # Using intermediate reasoning (like step-by-step breakdown)


# total_token_count: This is simply the sum of everything
   #prompt_token_count + candidates_token_count + thoughts_token_count = total_token_count

# %%
# response = client.models.generate_content(model='gemini-1.5-flash', contents='What is an car , explain in 400 words')
# print(response)

# %%
# generate_content()
# models -customize -- rude , polite , researcher , image
# parameter -config
# generatecontentconfig class object -- rule

from google.genai import types

# %%
# response = client.models.generate_content(
#     model='gemini-2.5-flash-lite',
#     contents='What is an car , explain in 400 words',
#     config= type.GenerateContentConfig()
#     )
# print(response)

# %%
# SYSTEM INSTRUCTIONS.
# model - persona...

# System instructions are special directives provided to AI models (like Gemini) to guide how they should behave during a
# conversation. These instructions are not visible to users in the typical interface but are set in the background by developers
# or platforms.
# They define the model’s
   #tone
   #personality
   #level of detail
   #preferred style of responses,
   #and even what it should or shouldn’t talk about.
# They allow developers to tailor the AI’s behavior to specific use cases—like customer support, education, or content generation—without
# needing to repeat instructions in every prompt.
# In essence, system instructions are like setting the "personality and boundaries" of an AI before it starts any conversation.

# %%
from google.genai import types

response = client.models.generate_content(
    model='gemini-2.5-flash-lite',
    contents='Hello there',
    config= types.GenerateContentConfig(system_instruction='You are an very polite person , you always speaks politely to people, but you never abuses.You give your output in very short lines or paragraphs')
    )

print(response.text)
# Out:
# Hello to you too!
# It's a pleasure to meet you.
# How may I be of assistance today?

# %%
# real world example of system instructions
client = genai.Client()


# detailed system instructions
system_instructions = """
 "You are a corporate legal assistant. "
            "Your job is to extract the following from any B2B contract text: "
            "1. Contract start and end dates, "
            "2. Payment terms, "
            "3. Termination conditions, "
            "4. Any penalty or liability clauses. "
            "Output only what you find."
            "I need the output in tabular form"
"""
# content
contents= """
        This agreement is entered into on May 1st, 2024 and shall remain in effect until April 30, 2025.
        Payment is due within 45 days of invoice date. Late payments may incur a penalty of 3% monthly.
        Either party may terminate this agreement with 60 days' notice.
    """

#model
response = client.models.generate_content(
    model="gemini-2.5-flash",
    config=types.GenerateContentConfig(
        system_instruction=system_instructions),
    contents=contents

)

print(response.text)
# Out:
# | Category                  | Details                                                  |
# | :------------------------ | :------------------------------------------------------- |
# | Contract Start Date       | May 1st, 2024                                            |
# | Contract End Date         | April 30, 2025                                           |
# | Payment Terms             | Payment is due within 45 days of invoice date.           |
# | Termination Conditions    | Either party may terminate with 60 days' notice.         |
# | Penalty/Liability Clauses | Late payments may incur a penalty of 3% monthly.         |

# %%
# max_output_tokens
# Sets a hard cap on how long the model’s response can be (1 token ≈ ¾ words).
response = client.models.generate_content(
    model='gemini-2.5-flash-lite',
    contents='what is an car',
    config= types.GenerateContentConfig(max_output_tokens=1000)
    )

print(response.text)
# Out:
# The word "car" is a common abbreviation for **automobile**.
#
# Here's a breakdown of what that means:
#
# *   **Automobile:** This is a self-propelled wheeled motor vehicle used for transportation. It typically runs on an engine (usually internal combustion or electric) and is designed to carry a relatively small number of passengers.
#
# **In simpler terms, a car is a vehicle you can drive yourself on roads to get from one place to another.**
#
# **Key characteristics of a car:**
#
# *   **Wheeled:** It has wheels to move.
# *   **Motorized:** It has an engine or motor that provides power.
# *   **Self-propelled:** It doesn't need to be pulled or pushed by another vehicle or animal.
# *   **Road vehicle:** It's designed for use on roads.
# *   **Passenger transport:** Its primary purpose is to carry people.
#
# Cars come in many shapes and sizes, including sedans, SUVs, trucks, vans, sports cars, and more.

# %%
# candidatecount Optional- Number of generated responses to return. If unset, this will default to 1. Please note that this doesn't work for
# previous generation models (Gemini 1.0 family)
response = client.models.generate_content(
    model='gemini-2.5-flash-lite',
    contents='what is an car in 100 words',
    config= types.GenerateContentConfig(candidateCount=2)
    )

print(response)
# Out:
# sdk_http_response=HttpResponse(
#   headers=<dict len=10>
# ) candidates=[Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text='A car, or automobile, is a wheeled motor vehicle used for transportation. It typically has four wheels, an engine (powered by gasoline, diesel, electricity, or hybrid systems), and a chassis that houses the engine, transmission, and passenger cabin. Cars are designed for carrying passengers and their luggage, offering a convenient and relatively independent mode of travel. They come in various shapes and sizes, from compact city cars to spacious SUVs and luxurious sedans. Their invention revolutionized personal mobility, allowing people to travel greater distances faster and more efficiently than ever before, shaping modern society and economies.'
#       ),
#       Part(
#         text="A car is a wheeled motor vehicle used for transportation. Typically seating one to eight people, it's designed primarily to transport people rather than cargo. Cars have an internal combustion engine or electric motor, allowing them to move independently. They feature a chassis, body, engine, transmission, wheels, and steering system. Essential for personal mobility, cars enable individuals to travel long distances, access jobs, and connect with others. From efficient compacts to spacious SUVs and powerful sports cars, the automobile has fundamentally reshaped modern life, offering convenience and freedom while also presenting challenges like pollution and traffic congestion."
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=0
# ), Candidate(
#   content=Content(
#     parts=[
#       Part(
#         text="A car is a wheeled motor vehicle used for transportation. Typically seating one to eight people, it's designed primarily to transport people rather than cargo. Cars have an internal combustion engine or electric motor, allowing them to move independently. They feature a chassis, body, engine, transmission, wheels, and steering system. Essential for personal mobility, cars enable individuals to travel long distances, access jobs, and connect with others. From efficient compacts to spacious SUVs and powerful sports cars, the automobile has fundamentally reshaped modern life, offering convenience and freedom while also presenting challenges like pollution and traffic congestion."
#       ),
#     ],
#     role='model'
#   ),
#   finish_reason=<FinishReason.STOP: 'STOP'>,
#   index=1
# )] create_time=None model_version='gemini-2.5-flash-lite' prompt_feedback=None response_id='LodLac7HI82JkdUPzfmRmQw' usage_metadata=GenerateContentResponseUsageMetadata(
#   candidates_token_count=116,
#   prompt_token_count=11,
#   prompt_tokens_details=[
#     ModalityTokenCount(
#       modality=<MediaModality.TEXT: 'TEXT'>,
#       token_count=11
#     ),
#   ],
#   total_token_count=127
# ) automatic_function_calling_history=[] parsed=None

# %%
for i, candidate  in enumerate(response.candidates):
  print(f"Candidate{i+1}: \n {candidate.content.parts[0].text}")
# Out:
# Candidate1:
#  A car, or automobile, is a wheeled motor vehicle used for transportation. It typically has four wheels, an engine (powered by gasoline, diesel, electricity, or hybrid systems), and a chassis that houses the engine, transmission, and passenger cabin. Cars are designed for carrying passengers and their luggage, offering a convenient and relatively independent mode of travel. They come in various shapes and sizes, from compact city cars to spacious SUVs and luxurious sedans. Their invention revolutionized personal mobility, allowing people to travel greater distances faster and more efficiently than ever before, shaping modern society and economies.
# Candidate2:
#  A car is a wheeled motor vehicle used for transportation. Typically seating one to eight people, it's designed primarily to transport people rather than cargo. Cars have an internal combustion engine or electric motor, allowing them to move independently. They feature a chassis, body, engine, transmission, wheels, and steering system. Essential for personal mobility, cars enable individuals to travel long distances, access jobs, and connect with others. From efficient compacts to spacious SUVs and powerful sports cars, the automobile has fundamentally reshaped modern life, offering convenience and freedom while also presenting challenges like pollution and traffic congestion.

# %%
# refer to document  for more  generationconfig parameters:- https://ai.google.dev/api/generate-content#v1beta.GenerationConfig

# %%
# MULTI MODEL INPUT
from PIL import Image
from io  import BytesIO
import base64

client= genai.Client()


image = Image.open("/content/sample_data/Screenshot 2025-08-28 185053.png")
response = client.models.generate_content(
    model='gemini-2.5-flash',
    contents= [image, 'Write an short story  about the image in 100 words, in simple english']
)

print(response.text)
# Out:
# Alex, a curious cloud learner, started their day at the terminal. First, they set up their AWS connection. Then, they peeked into different regions and saw what machine images were available.
#
# With a new key called "new4545," Alex launched two small `t2.micro` servers. Later, they practiced stopping one of these servers, checking its status, and bringing it back online. They also searched to see all their `t2.micro` servers, even looking across different regions. Finally, with their tasks complete, Alex cleared the screen, ready for the next cloud adventure.

# %% [markdown]
# # IMAGE GENERATION

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
# Initialize the GenAI client
client = genai.Client()


# Generate content using the Gemini image generation preview model
response = client.models.generate_content(
    model="gemini-2.0-flash-preview-image-generation",
    contents='Hi, can you create a 3d rendered image of a dog covered in mud full running on the road of lust green city',
    config=types.GenerateContentConfig(
      response_modalities=['TEXT', 'IMAGE']

    )
)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /tmp/ipython-input-413180094.py in <cell line: 0>()
#       4
#       5 # Generate content using the Gemini image generation preview model
# ----> 6 response = client.models.generate_content(
#       7     model="gemini-2.0-flash-preview-image-generation",
#       8     contents='Hi, can you create a 3d rendered image of a dog covered in mud full running on the road of lust green city',
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5228     while remaining_remote_calls_afc > 0:
#    5229       i += 1
# -> 5230       response = self._generate_content(
#    5231           model=model, contents=contents, config=parsed_config
#    5232       )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4010     request_dict = _common.encode_unserializable_types(request_dict)
#    4011
# -> 4012     response = self._api_client.request(
#    4013         'post', path, request_dict, http_options
#    4014     )
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1386         http_method, path, request_dict, http_options
#    1387     )
# -> 1388     response = self._request(http_request, http_options, stream=False)
#    1389     response_body = (
#    1390         response.response_stream[0] if response.response_stream else ''
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1222         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1223
# -> 1224     return self._retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1225
#    1226   async def _async_request_once(
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     475         retry_state = RetryCallState(retry_object=self, fn=fn, args=args, kwargs=kwargs)
#     476         while True:
# --> 477             do = self.iter(retry_state=retry_state)
#     478             if isinstance(do, DoAttempt):
#     479                 try:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     376         result = None
#     377         for action in self.iter_state.actions:
# --> 378             result = action(retry_state)
#     379         return result
#     380
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     418                 retry_exc = self.retry_error_cls(fut)
#     419                 if self.reraise:
# --> 420                     raise retry_exc.reraise()
#     421                 raise retry_exc from fut.exception()
#     422
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     185     def reraise(self) -> t.NoReturn:
#     186         if self.last_attempt.failed:
# --> 187             raise self.last_attempt.result()
#     188         raise self
#     189
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     447                     raise CancelledError()
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#     451                 self._condition.wait(timeout)
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     399         if self._exception:
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#     403                 # Break a reference cycle with the exception in self._exception
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     478             if isinstance(do, DoAttempt):
#     479                 try:
# --> 480                     result = fn(*args, **kwargs)
#     481                 except BaseException:  # noqa: B902
#     482                     retry_state.set_exception(sys.exc_info())  # type: ignore[arg-type]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1199           timeout=http_request.timeout,
#    1200       )
# -> 1201       errors.APIError.raise_for_response(response)
#    1202       return HttpResponse(
#    1203           response.headers, response if stream else [response.text]
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     119       response_json = response.body_segments[0].get('error', {})
#     120
# --> 121     cls.raise_error(response.status_code, response_json, response)
#     122
#     123   @classmethod
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     144     """
#     145     if 400 <= status_code < 500:
# --> 146       raise ClientError(status_code, response_json, response)
#     147     elif 500 <= status_code < 600:
#     148       raise ServerError(status_code, response_json, response)
#
# ClientError: 404 NOT_FOUND. {'error': {'code': 404, 'message': 'models/gemini-2.0-flash-preview-image-generation is not found for API version v1beta, or is not supported for generateContent. Call ListModels to see the list of available models and their supported methods.', 'status': 'NOT_FOUND'}}

# %%
response.candidates[0].content.parts[0].text

# %%
data = response.candidates[0].content.parts[1].inline_data.data

# %%
with open("Running_Dog.png", 'wb') as f:
  f.write(data)

from IPython.display import display
image= Image.open(BytesIO(data))
display(image)

# %%
# image edit
# i/p- image+text
# o/p - image

import PIL.Image

image= PIL.Image.open('/content/Ai robot.jpg')



# Initialize the GenAI client
client = genai.Client()


# Generate content using the Gemini image generation preview model
response = client.models.generate_content(
    model="gemini-2.0-flash-preview-image-generation",
    contents=[image,'Hi, for this Robot Picture make the background  as an high tech city , with flying cars and show  robot standing at the middle of the city on an road'],
    config=types.GenerateContentConfig(
      response_modalities=['TEXT', 'IMAGE']

    )
)

# %%
data = response.candidates[0].content.parts[0].inline_data.data

from IPython.display import display
image= Image.open(BytesIO(data))
display(image)

# %%
image = PIL.Image.open('/content/furnished room.jpeg')

client = genai.Client()

text_input = ("What other color and design sofas would work in my room update the image with the sofa design and colour")

response = client.models.generate_content(
    model="gemini-2.0-flash-preview-image-generation",
    contents=[text_input, image],
    config=types.GenerateContentConfig(
      response_modalities=['TEXT', 'IMAGE']
    )
)

response

# %%
data = response.candidates[0].content.parts[1].inline_data.data

from IPython.display import display
image= Image.open(BytesIO(data))
display(image)

# %%
# image editing
# i/p- text+image
# output- image+text


image = PIL.Image.open('/content/furnished room.jpeg')

client = genai.Client()

text_input = ("Write an quote on the blue color wall of the room :-'You can do it , You will do it, You did it' and give me an HD image")

response = client.models.generate_content(
    model="gemini-2.0-flash-preview-image-generation",
    contents=[text_input, image],
    config=types.GenerateContentConfig(
      response_modalities=['TEXT', 'IMAGE']
    )
)

response

# %%
data= response.candidates[0].content.parts[0].inline_data.data
from IPython.display import display
image= Image.open(BytesIO(data))
display(image)

# %% [markdown]
# # SPEECH GENERATION

# %%
# text --> audio
# modality --> audio

# Single voice
# congfig-- GenerateContentConfig -- SpeechConfig  -- voiceConfig -- prebuiltVoiceConfig -- voice_name



response = client.models.generate_content(
    model="gemini-2.5-flash-preview-tts",
    contents="Say angrly : Hey How are you?",
    config=types.GenerateContentConfig(
      response_modalities=['AUDIO'],
      speech_config= types.SpeechConfig(
          voice_config= types.VoiceConfig(
              prebuilt_voice_config= types.PrebuiltVoiceConfig(
                  voice_name='Kore'
              )
          )
      ),
    )
)

print(response)

# %%
data= response.candidates[0].content.parts[0].inline_data.data
#channel- 1(mono), 2(stereo)
#samplewidth- clearity 1-8bits , 2-16 bits
#framerate-

# .wav
import wave

def wave_file(filename, input):
  with wave.open(filename, 'wb') as wf:
    wf.setnchannels(1)
    wf.setsampwidth(2)
    wf.setframerate(24000)
    wf.writeframes(input)

# %%
file_name='Out.wav'
wave_file(file_name, data)

from IPython.display import Audio
Audio('Out.wav')

# %%
# MULTI TONE PARAGRAPH
response = client.models.generate_content(
    model="gemini-2.5-flash-preview-tts",
     contents=[
        "Say cheerfully: Good morning!",
        "Say excitedly: Today is a big day.",
        "Say angrly: Stay calm and give it your best.",
        "Say encouragingly: You're going to do great.",
        "Say Sadly: I wish I could also come."
    ],
    config=types.GenerateContentConfig(
      response_modalities=['AUDIO'],
      speech_config= types.SpeechConfig(
          voice_config= types.VoiceConfig(
              prebuilt_voice_config= types.PrebuiltVoiceConfig(
                  voice_name='Kore'
              )
          )
      ),
    )
)

# %%
data= response.candidates[0].content.parts[0].inline_data.data
file_name='Out.wav'
wave_file(file_name, data)

from IPython.display import Audio
Audio('Out.wav')

# %%
# muliple voice
prompt = """TTS the following conversation between Joe and Jane:
         Anya: Good morning, Liam. Based on the recent climate model, we might need to update our energy distribution strategy.
         Liam:Morning, Dr. Anya. I was reviewing the latest projections last night. It looks like solar output might drop by 20% in the northern grid.
         Anya:  Exactly. That could impact the balance in real-time supply-demand. Let’s consider rerouting some wind power reserves.
         Liam: NI’ll run the simulation and share the updated dashboard with the operations team. Should we also notify regional operators?
         """

# %%
# congfig-- GenerateContentConfig -- SpeechConfig  --multiSpeakerVoiceConfig --speakerVoiceConfigs(speaker)--
# --voiceConfig -- prebuiltVoiceConfig -- voice_name


response = client.models.generate_content(
   model="gemini-2.5-flash-preview-tts",contents=prompt,
   config=types.GenerateContentConfig( response_modalities=["AUDIO"],
      speech_config=types.SpeechConfig(
         multi_speaker_voice_config=types.MultiSpeakerVoiceConfig(
            speaker_voice_configs=[

               types.SpeakerVoiceConfig(
                  speaker='Anya',
                  voice_config=types.VoiceConfig(
                     prebuilt_voice_config=types.PrebuiltVoiceConfig(
                        voice_name='Kore',
                     )
                  )
               ),
               types.SpeakerVoiceConfig(
                  speaker='Liam',
                  voice_config=types.VoiceConfig(
                     prebuilt_voice_config=types.PrebuiltVoiceConfig(
                        voice_name='Puck',
                     )
                  )
               ),
            ]
         )
      )
   )
)

# %%
data= response.candidates[0].content.parts[0].inline_data.data
file_name='Out.wav'
wave_file(file_name, data)

from IPython.display import Audio
Audio('Out.wav')
